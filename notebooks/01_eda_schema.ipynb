# %% [markdown]
# # 01 – GA4 Schema & Session-Level Feasibility
#
# ## Objective
# Explore the GA4 sample dataset to understand event structure, session
# reconstruction, and feasibility of building a session-level dataset
# for customer-journey diagnostics and modeling.
#
# ## Key questions
# - What events exist and how frequent are they?
# - How are sessions identified?
# - How many sessions end in a purchase?
# - Which session-level features are feasible?

# %%
from google.cloud import bigquery
import pandas as pd

PROJECT_ID = "wide-origin-477108-i9"

client = bigquery.Client(project=PROJECT_ID)
client.project
# Out:
# 'wide-origin-477108-i9'

# %%
dataset_id = "bigquery-public-data.ga4_obfuscated_sample_ecommerce"

datasets = [d.dataset_id for d in client.list_datasets("bigquery-public-data")]
"ga4_obfuscated_sample_ecommerce" in datasets
# Out:
# True

# %%
import sys
# !{sys.executable} -m pip install db-dtypes
# Out:
# Collecting db-dtypes
#   Using cached db_dtypes-1.5.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.24.0 in /Users/clairedebadts/code/clairedebadts-cloud/customer-journey-diagnostics/.venv/lib/python3.12/site-packages (from db-dtypes) (2.3.5)
# Requirement already satisfied: packaging>=24.2.0 in /Users/clairedebadts/code/clairedebadts-cloud/customer-journey-diagnostics/.venv/lib/python3.12/site-packages (from db-dtypes) (25.0)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /Users/clairedebadts/code/clairedebadts-cloud/customer-journey-diagnostics/.venv/lib/python3.12/site-packages (from db-dtypes) (2.3.3)
# Requirement already satisfied: pyarrow>=13.0.0 in /Users/clairedebadts/code/clairedebadts-cloud/customer-journey-diagnostics/.venv/lib/python3.12/site-packages (from db-dtypes) (22.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/clairedebadts/code/clairedebadts-cloud/customer-journey-diagnostics/.venv/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/clairedebadts/code/clairedebadts-cloud/customer-journey-diagnostics/.venv/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/clairedebadts/code/clairedebadts-cloud/customer-journey-diagnostics/.venv/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/clairedebadts/code/clairedebadts-cloud/customer-journey-diagnostics/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.5.3->db-dtypes) (1.17.0)
# Using cached db_dtypes-1.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: db-dtypes
# Successfully installed db-dtypes-1.5.0

# %%
query = """
SELECT
  event_name,
  COUNT(*) AS n_events
FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_*`
GROUP BY event_name
ORDER BY n_events DESC
LIMIT 30
"""

df_events = client.query(query).to_dataframe()
df_events
# Out:
# /Users/clairedebadts/code/clairedebadts-cloud/customer-journey-diagnostics/.venv/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#              event_name  n_events
# 0             page_view   1350428
# 1       user_engagement   1058721
# 2                scroll    493072
# 3             view_item    386068
# 4         session_start    354970
# 5           first_visit    257462
# 6        view_promotion    190104
# 7           add_to_cart     58543
# 8        begin_checkout     38757
# 9           select_item     31007
# 10  view_search_results     26172
# 11    add_shipping_info     19722
# 12     add_payment_info     13899
# 13     select_promotion      9450
# 14             purchase      5692
# 15                click      1446
# 16       view_item_list        71

# %% [markdown]
# ### Observations
# - These events define the potential funnel.
# - Purchase events exist and can be used as a session-level target (y).
# - Event counts suggest strong class imbalance (expected in e-commerce).

# %%
query = """
SELECT
  event_name,
  event_timestamp,
  user_pseudo_id,
  event_params
FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_*`
LIMIT 5
"""

client.query(query).to_dataframe()
# Out:
# /Users/clairedebadts/code/clairedebadts-cloud/customer-journey-diagnostics/.venv/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#         event_name   event_timestamp      user_pseudo_id  \
# 0        page_view  1609568188059459  1005484.1092567297
# 1  user_engagement  1609568195189041  1005484.1092567297
# 2      first_visit  1609568182969088  1005484.1092567297
# 3        page_view  1609568182969088  1005484.1092567297
# 4    session_start  1609568182969088  1005484.1092567297
#
#                                         event_params
# 0  [{'key': 'gclsrc', 'value': {'string_value': N...
# 1  [{'key': 'gclid', 'value': {'string_value': No...
# 2  [{'key': 'page_title', 'value': {'string_value...
# 3  [{'key': 'all_data', 'value': {'string_value':...
# 4  [{'key': 'ga_session_number', 'value': {'strin...
